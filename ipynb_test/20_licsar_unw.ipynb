# %%
# Perhaps you want to check reunw of such pair separately – I (had a minute so…) tried following and the result looks great!
import os
import lics_unwrap as lu
frame='116A_05207_252525'
pair='20230417_20230511'
procpairdir = '/work/scratch-pw2/licsar/mnergiz/TR_interseismic_postseismic-upt-17052027/trial'
a=lu.process_ifg(frame, pair, procpairdir,  ml=10 , hgtcorr = False, thres = 0.2, keep_coh_debug = True, specmag = False, subtract_gacos = True)
# a=lu.process_ifg(frame, pair, procpairdir, lowpass=False, pre_detrend=False)
a.unw.plot()

# # Maybe try with the other pair that you think might be erroneous?

# # M
# Out:
# loading the unfiltered ifg
# preparing GACOS correction
# GACOS data found, using to improve unwrapping
# GACOS decreases avg coh by -0.000714564108617. Skipping use of GACOS to support unwrapping
# instead, trying hgtcorr...
# detrending by 3/-3 fringes in lon/lat
# calculating correlation with DEM
# filter using gauss filter
# using U to improve hgt corr
# Elapsed time for hgt correction: 0.589331
# we use average value of -5.2 rad/km
# warning, the heights correction would increase overall complex std by 0.130371684617 - might be worse then? (checking with coh change)
# /gws/smf/j04/nceo_geohazards/software/mambalics/lib/python3.8/site-packages/xarray/core/computation.py:771: RuntimeWarning: divide by zero encountered in divide
#   result_data = func(*input_data)
# the heights correction would decrease avg coh by -0.0102158107093. Skipping.
# detrending by 2/1 fringes in lon/lat
# filter using gauss filter
# ...
