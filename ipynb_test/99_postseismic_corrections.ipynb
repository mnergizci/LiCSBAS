# %%
#%% Import 
import os
import sys
import getopt
import h5py as h5
import numpy as np
import pandas as pd
import datetime as dt
import daz_lib_licsar as dl
import xarray as xr
import matplotlib.pyplot as plt
# Out:
# ERROR 1: /opt/jaspy/lib/gdalplugins/.././libspatialite.so.8: undefined symbol: freexl_open_ods
# ERROR 1: /opt/jaspy/lib/gdalplugins/.././libspatialite.so.8: undefined symbol: freexl_open_ods
# ERROR 1: /opt/jaspy/lib/gdalplugins/.././libspatialite.so.8: undefined symbol: freexl_open_ods
# ERROR 1: /opt/jaspy/lib/gdalplugins/.././libspatialite.so.8: undefined symbol: freexl_open_ods
# ERROR 1: /opt/jaspy/lib/gdalplugins/.././libspatialite.so.8: undefined symbol: freexl_open_ods
# ERROR 1: /opt/jaspy/lib/gdalplugins/.././libspatialite.so.8: undefined symbol: freexl_open_ods
# ERROR 1: /opt/jaspy/lib/gdalplugins/.././libspatialite.so.8: undefined symbol: freexl_open_ods
# ERROR 1: /opt/jaspy/lib/gdalplugins/.././libspatialite.so.8: undefined symbol: freexl_open_ods
# ERROR 1: /opt/jaspy/lib/gdalplugins/.././libspatialite.so.8: undefined symbol: freexl_open_ods
# ERROR 1: /opt/jaspy/lib/gdalplugins/.././libspatialite.so.8: undefined symbol: freexl_open_ods
# ...

# %%
sboi_014='/gws/nopw/j04/nceo_geohazards_vol2/LiCS/temp/insar_proc/mnergizci/1.postseismic_dataset_backup_04122025/ranges/021D_05266_252525'
frame=os.path.basename(sboi_014)
cumfile=os.path.join(sboi_014,'TS_GEOCml10GACOS/cum_filt_interpolate.h5')
sboi_014_cum = xr.load_dataset(cumfile)

# %%
sboi_014_cum.cum[-4].plot(vmin=-100, vmax=100, cmap="RdBu")
